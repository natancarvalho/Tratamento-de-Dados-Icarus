# %%
# Importando bibliotecas para análise
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as st
import plotly.offline as py
import plotly.graph_objs as go

from scipy.special import boxcox1p

py.init_notebook_mode(connected=True)

#Importando dados em CSV para um data frame

PedraoMetadeEnduroLap3 = pd.read_csv('./PedraoMetadeEnduroLap3.csv')
PedraoMetadeEnduroLap4 = pd.read_csv('./PedraoMetadeEnduroLap4.csv')
PedraoMetadeEnduroLap5 = pd.read_csv('./PedraoMetadeEnduroLap5.csv')
PedraoMetadeEnduroLap6 = pd.read_csv('./PedraoMetadeEnduroLap6.csv')
PedraoMetadeEnduroLap7 = pd.read_csv('./PedraoMetadeEnduroLap7.csv')
PedraoMetadeEnduroLap8 = pd.read_csv('./PedraoMetadeEnduroLap8.csv')
PedraoMetadeEnduroLap9 = pd.read_csv('./PedraoMetadeEnduroLap9.csv')
PedraoMetadeEnduroLap10 = pd.read_csv('./PedraoMetadeEnduroLap10.csv')
PedraoMetadeEnduroLap11 = pd.read_csv('./PedraoMetadeEnduroLap11.csv')
PedraoMetadeEnduroLap12 = pd.read_csv('./PedraoMetadeEnduroLap12.csv')
PedraoMetadeEnduroLap13 = pd.read_csv('./PedraoMetadeEnduroLap13.csv')
PedraoMetadeEnduroLap14 = pd.read_csv('./PedraoMetadeEnduroLap14.csv')
PedraoMetadeEnduroLap15 = pd.read_csv('./PedraoMetadeEnduroLap15.csv')
PedraoMetadeEnduroLap16 = pd.read_csv('./PedraoMetadeEnduroLap16.csv')
PedraoMetadeEnduroLap17 = pd.read_csv('./PedraoMetadeEnduroLap17.csv')
PedraoMetadeEnduroLap18 = pd.read_csv('./PedraoMetadeEnduroLap18.csv')
PedraoMetadeEnduroLap19 = pd.read_csv('./PedraoMetadeEnduroLap19.csv')
PedraoMetadeEnduroLap20 = pd.read_csv('./PedraoMetadeEnduroLap20.csv')
PedraoMetadeEnduroLap21 = pd.read_csv('./PedraoMetadeEnduroLap21.csv')
PedraoMetadeEnduroLap22 = pd.read_csv('./PedraoMetadeEnduroLap22.csv')


#Exibindo a quantidade de linhas x colunas do data frame
print(PedraoMetadeEnduroLap10.shape)
print(PedraoMetadeEnduroLap3.shape)
print(PedraoMetadeEnduroLap4.shape)
print(PedraoMetadeEnduroLap5.shape)
print(PedraoMetadeEnduroLap6.shape)
print(PedraoMetadeEnduroLap7.shape)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# (890, 6)
# (963, 6)
# (872, 6)
# (862, 6)
# (862, 6)
# (939, 6)

# %%
PedraoLap3.describe ()
#JaguarLap1.describe().to_excel("JaguarLap1.xlsx")
# Out:
#              Time    Distance  AccelerometerY           RPM   GPS_Speed  \
# count  987.000000  987.000000      987.000000    987.000000  987.000000
# mean     9.859981    0.079210        0.239867   4918.434501   29.569034
# std      5.701300    0.047368        0.567370   1366.006913    7.464574
# min      0.000000    0.000000       -0.881082    488.988861   20.504000
# 25%      4.930000    0.042000       -0.159438   4103.772705   24.260001
# 50%      9.860000    0.075000        0.208453   4663.864258   27.132000
# 75%     14.790000    0.121000        0.803672   5367.365234   34.038002
# max     19.701000    0.162000        1.019760  10347.966797   53.596001
#
#        GPS_LatAcc  GPS_LonAcc
# count  987.000000  987.000000
# mean     0.226570    0.005289
# std      0.491815    0.243923
# min     -0.759191   -0.600090
# 25%     -0.114705   -0.173167
# 50%      0.141804    0.029903
# 75%      0.646207    0.188794
# max      1.396043    0.600690

# %%
JaguarLap2.describe ()

# %%
JaguarLap3.describe()

# %%
PedraoLap1.head()
# Out:
#    Time  Distance  AccelerometerY          RPM  GPS_Speed  GPS_LatAcc  \
# 0  0.00     0.000       -0.178206  4388.957520  26.089001   -0.593003
# 1  0.02     0.000       -0.212743  4396.266113  26.091000   -0.618732
# 2  0.04     0.000       -0.248172  4414.872070  26.071001   -0.642568
# 3  0.06     0.000       -0.284444  4428.844238  26.051001   -0.666404
# 4  0.08     0.001       -0.320933  4430.755371  26.031000   -0.690239
#
#    GPS_LonAcc
# 0    0.020012
# 1    0.008362
# 2    0.004283
# 3    0.000204
# 4   -0.003875

# %%
JaguarLap2.head()
# Out:
#    Time  Distance      Pant     Ppost   LongAcc    LatAcc  LoggerTemp  \
# 0   0.0     0.000  0.021973  0.000000 -0.275071  0.037933    28.97403
# 1   0.1     0.004  0.000000  0.000000 -0.291513  0.034282    28.97403
# 2   0.2     0.009  0.000000  0.000000 -0.184179  0.036364    28.97403
# 3   0.3     0.014  0.000000  0.000000 -0.005050  0.042353    28.97403
# 4   0.4     0.018  0.002441 -0.004883  0.086126  0.045313    28.97403
#
#      Battery          RPM       TPS1  ...   GPS_Speed  GPS_Nsat  GPS_LatAcc  \
# 0  13.633484  6434.500000  99.999985  ...  160.210007       9.0    0.053089
# 1  13.628540  6405.700195  93.176453  ...  161.339996       8.9    0.048437
# 2  13.628540  6370.700195  28.627447  ...  162.710007       8.0    0.041554
# 3  13.628540  5797.000000   3.921568  ...  163.819992       8.2    0.030273
# 4  13.630737  5424.100098  42.117638  ...  165.010010      10.0    0.021032
#
#    GPS_LonAcc  GPS_Slope  GPS_Heading  GPS_Gyro  GPS_Latitude  GPS_Longitude  \
# ...

# %%
JaguarLap3.head()

# %%
#Diagrama GG de aceleração longitudinal x aceleração lateral

plt.scatter(PedraoMetadeEnduroLap3['GPS_LatAcc']*-1, PedraoMetadeEnduroLap3['GPS_LonAcc'], label="3ª Volta")
plt.scatter(PedraoMetadeEnduroLap4['GPS_LatAcc']*-1, PedraoMetadeEnduroLap4['GPS_LonAcc'], label="4ª Volta")
plt.scatter(PedraoMetadeEnduroLap5['GPS_LatAcc']*-1, PedraoMetadeEnduroLap5['GPS_LonAcc'], label="5ª Volta")
plt.scatter(PedraoMetadeEnduroLap6['GPS_LatAcc']*-1, PedraoMetadeEnduroLap6['GPS_LonAcc'], label="6ª Volta")
plt.scatter(PedraoMetadeEnduroLap7['GPS_LatAcc']*-1, PedraoMetadeEnduroLap7['GPS_LonAcc'], label="7ª Volta")
plt.scatter(PedraoMetadeEnduroLap8['GPS_LatAcc']*-1, PedraoMetadeEnduroLap8['GPS_LonAcc'], label="8ª Volta")
plt.scatter(PedraoMetadeEnduroLap9['GPS_LatAcc']*-1, PedraoMetadeEnduroLap9['GPS_LonAcc'], label="9ª Volta")
plt.scatter(PedraoMetadeEnduroLap10['GPS_LatAcc']*-1, PedraoMetadeEnduroLap10['GPS_LonAcc'], label="10ª Volta")
plt.scatter(PedraoMetadeEnduroLap11['GPS_LatAcc']*-1, PedraoMetadeEnduroLap11['GPS_LonAcc'], label="11ª Volta")
plt.scatter(PedraoMetadeEnduroLap12['GPS_LatAcc']*-1, PedraoMetadeEnduroLap12['GPS_LonAcc'], label="12ª Volta")
plt.scatter(PedraoMetadeEnduroLap13['GPS_LatAcc']*-1, PedraoMetadeEnduroLap13['GPS_LonAcc'], label="13ª Volta")
plt.scatter(PedraoMetadeEnduroLap15['GPS_LatAcc']*-1, PedraoMetadeEnduroLap15['GPS_LonAcc'], label="15ª Volta")
plt.scatter(PedraoMetadeEnduroLap16['GPS_LatAcc']*-1, PedraoMetadeEnduroLap16['GPS_LonAcc'], label="16ª Volta")
plt.scatter(PedraoMetadeEnduroLap17['GPS_LatAcc']*-1, PedraoMetadeEnduroLap17['GPS_LonAcc'], label="17ª Volta")
plt.scatter(PedraoMetadeEnduroLap18['GPS_LatAcc']*-1, PedraoMetadeEnduroLap18['GPS_LonAcc'], label="18ª Volta")
plt.scatter(PedraoMetadeEnduroLap19['GPS_LatAcc']*-1, PedraoMetadeEnduroLap19['GPS_LonAcc'], label="19ª Volta")
plt.scatter(PedraoMetadeEnduroLap20['GPS_LatAcc']*-1, PedraoMetadeEnduroLap20['GPS_LonAcc'], label="20ª Volta")
plt.scatter(PedraoMetadeEnduroLap21['GPS_LatAcc']*-1, PedraoMetadeEnduroLap21['GPS_LonAcc'], label="21ª Volta")
plt.scatter(PedraoMetadeEnduroLap22['GPS_LatAcc']*-1, PedraoMetadeEnduroLap22['GPS_LonAcc'], label="22ª Volta")

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.title('Gráficos GG na Metade Enduro Pedrao 1109') #adicionando o título
plt.xlabel('Aceleração Lateral')
plt.ylabel('Aceleração Longitudinal')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
plt.savefig('Gráficos GG na Metade Enduro Pedrao 1109.png')
plt.show()

# %%
# Removendo dados de aceleração longitudinal acima de 0.7
JaguarLap7 = JaguarLap7.drop(JaguarLap7[(JaguarLap7.GPS_LonAcc < -0.9) & (JaguarLap7.LatAcc < -0.5)].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-39fa4b3082ee> in <module>
#       1 # Removendo dados de aceleração longitudinal acima de 0.7
# ----> 2 JaguarLap7 = JaguarLap7.drop(JaguarLap7[(JaguarLap7.GPS_LonAcc < -0.9) & (JaguarLap7.LatAcc < -0.5)].index)
#
# NameError: name 'JaguarLap7' is not defined

# %%
#Graficos de Velocidade x Distância

plt.plot(PedraoMetadeEnduroLap3['Distance'], PedraoMetadeEnduroLap3['GPS_Speed'], label="3ª Volta")
plt.plot(PedraoMetadeEnduroLap4['Distance'], PedraoMetadeEnduroLap4['GPS_Speed'], label="4ª Volta")
plt.plot(PedraoMetadeEnduroLap5['Distance'], PedraoMetadeEnduroLap5['GPS_Speed'], label="5ª Volta")
plt.plot(PedraoMetadeEnduroLap6['Distance'], PedraoMetadeEnduroLap6['GPS_Speed'], label="6ª Volta")
plt.plot(PedraoMetadeEnduroLap7['Distance'], PedraoMetadeEnduroLap7['GPS_Speed'], label="7ª Volta")
plt.plot(PedraoMetadeEnduroLap8['Distance'], PedraoMetadeEnduroLap8['GPS_Speed'], label="8ª Volta")
plt.plot(PedraoMetadeEnduroLap9['Distance'], PedraoMetadeEnduroLap9['GPS_Speed'], label="9ª Volta")
plt.plot(PedraoMetadeEnduroLap10['Distance'], PedraoMetadeEnduroLap10['GPS_Speed'], label="10ª Volta")
plt.plot(PedraoMetadeEnduroLap11['Distance'], PedraoMetadeEnduroLap11['GPS_Speed'], label="11ª Volta")
plt.plot(PedraoMetadeEnduroLap12['Distance'], PedraoMetadeEnduroLap12['GPS_Speed'], label="12ª Volta")
plt.plot(PedraoMetadeEnduroLap13['Distance'], PedraoMetadeEnduroLap13['GPS_Speed'], label="13ª Volta")
plt.plot(PedraoMetadeEnduroLap15['Distance'], PedraoMetadeEnduroLap15['GPS_Speed'], label="15ª Volta")
plt.plot(PedraoMetadeEnduroLap16['Distance'], PedraoMetadeEnduroLap16['GPS_Speed'], label="16ª Volta")
plt.plot(PedraoMetadeEnduroLap17['Distance'], PedraoMetadeEnduroLap17['GPS_Speed'], label="17ª Volta")
plt.plot(PedraoMetadeEnduroLap18['Distance'], PedraoMetadeEnduroLap18['GPS_Speed'], label="18ª Volta")
plt.plot(PedraoMetadeEnduroLap19['Distance'], PedraoMetadeEnduroLap19['GPS_Speed'], label="19ª Volta")
plt.plot(PedraoMetadeEnduroLap20['Distance'], PedraoMetadeEnduroLap20['GPS_Speed'], label="20ª Volta")
plt.plot(PedraoMetadeEnduroLap21['Distance'], PedraoMetadeEnduroLap21['GPS_Speed'], label="21ª Volta")
plt.plot(PedraoMetadeEnduroLap22['Distance'], PedraoMetadeEnduroLap22['GPS_Speed'], label="22ª Volta")

plt.title('Gráfico de Vel. x Distância na Metade Enduro Pedrao 1109') #adicionando o título
plt.xlabel('Distância (Km)')
plt.ylabel('Velocidade (Km/h)')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
#plt.plot.yticks(range(0, 54))
plt.savefig('Gráfico de velocidade x distância na Metade Enduro Pedrao 1109.png')
plt.show()

# %%
#Histogramas de RPM

PedraoMetadeEnduroLap3['RPM'].fillna(PedraoMetadeEnduroLap3['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap3['RPM'], bins = 10, label = "3ª Volta")

PedraoMetadeEnduroLap4['RPM'].fillna(PedraoMetadeEnduroLap4['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap4['RPM'], bins = 10, label = "4ª Volta")

PedraoMetadeEnduroLap5['RPM'].fillna(PedraoMetadeEnduroLap5['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap5['RPM'], bins = 10, label = "5ª Volta")
         
PedraoMetadeEnduroLap6['RPM'].fillna(PedraoMetadeEnduroLap6['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap6['RPM'], bins = 10, label = "6ª Volta")

PedraoMetadeEnduroLap7['RPM'].fillna(PedraoMetadeEnduroLap7['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap7['RPM'], bins = 10, label = "7ª Volta")

PedraoMetadeEnduroLap8['RPM'].fillna(PedraoMetadeEnduroLap8['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap8['RPM'], bins = 10, label = "8ª Volta")

PedraoMetadeEnduroLap9['RPM'].fillna(PedraoMetadeEnduroLap9['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap9['RPM'], bins = 10, label = "9ª Volta")

PedraoMetadeEnduroLap10['RPM'].fillna(PedraoMetadeEnduroLap10['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap10['RPM'], bins = 10, label = "10ª Volta")

PedraoMetadeEnduroLap11['RPM'].fillna(PedraoMetadeEnduroLap11['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap11['RPM'], bins = 10, label = "11ª Volta")

PedraoMetadeEnduroLap12['RPM'].fillna(PedraoMetadeEnduroLap12['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap12['RPM'], bins = 10, label = "12ª Volta")

PedraoMetadeEnduroLap13['RPM'].fillna(PedraoMetadeEnduroLap13['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap13['RPM'], bins = 10, label = "13ª Volta")

PedraoMetadeEnduroLap15['RPM'].fillna(PedraoMetadeEnduroLap15['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap15['RPM'], bins = 10, label = "15ª Volta")
         
PedraoMetadeEnduroLap16['RPM'].fillna(PedraoMetadeEnduroLap16['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap16['RPM'], bins = 10, label = "16ª Volta")

PedraoMetadeEnduroLap17['RPM'].fillna(PedraoMetadeEnduroLap17['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap17['RPM'], bins = 10, label = "17ª Volta")

PedraoMetadeEnduroLap18['RPM'].fillna(PedraoMetadeEnduroLap18['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap18['RPM'], bins = 10, label = "18ª Volta")

PedraoMetadeEnduroLap19['RPM'].fillna(PedraoMetadeEnduroLap19['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap19['RPM'], bins = 10, label = "19ª Volta")

PedraoMetadeEnduroLap20['RPM'].fillna(PedraoMetadeEnduroLap20['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap20['RPM'], bins = 10, label = "20ª Volta")

PedraoMetadeEnduroLap21['RPM'].fillna(PedraoMetadeEnduroLap21['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap21['RPM'], bins = 10, label = "21ª Volta")

PedraoMetadeEnduroLap22['RPM'].fillna(PedraoMetadeEnduroLap22['RPM'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap22['RPM'], bins = 10, label = "22ª Volta")

plt.title('Histograma RPM na Metade Enduro Pedrao 1109')
plt.xlabel('RPM') 
plt.ylabel('Contagem de amostras')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
plt.show
plt.savefig('Histograma RPM na Metade Enduro Pedrao 1109')

# %%
#Histogramas de Velocidade

PedraoMetadeEnduroLap3['GPS_Speed'].fillna(PedraoMetadeEnduroLap3['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap3['GPS_Speed'], bins = 10, label = "3ª Volta")

PedraoMetadeEnduroLap4['GPS_Speed'].fillna(PedraoMetadeEnduroLap4['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap4['GPS_Speed'], bins = 10, label = "4ª Volta")

PedraoMetadeEnduroLap5['GPS_Speed'].fillna(PedraoMetadeEnduroLap5['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap5['GPS_Speed'], bins = 10, label = "5ª Volta")
         
PedraoMetadeEnduroLap6['GPS_Speed'].fillna(PedraoMetadeEnduroLap6['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap6['GPS_Speed'], bins = 10, label = "6ª Volta")

PedraoMetadeEnduroLap7['GPS_Speed'].fillna(PedraoMetadeEnduroLap7['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap7['GPS_Speed'], bins = 10, label = "7ª Volta")

PedraoMetadeEnduroLap8['GPS_Speed'].fillna(PedraoMetadeEnduroLap8['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap8['GPS_Speed'], bins = 10, label = "8ª Volta")

PedraoMetadeEnduroLap9['GPS_Speed'].fillna(PedraoMetadeEnduroLap9['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap9['GPS_Speed'], bins = 10, label = "9ª Volta")

PedraoMetadeEnduroLap10['GPS_Speed'].fillna(PedraoMetadeEnduroLap10['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap10['GPS_Speed'], bins = 10, label = "10ª Volta")

PedraoMetadeEnduroLap11['GPS_Speed'].fillna(PedraoMetadeEnduroLap11['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap11['GPS_Speed'], bins = 10, label = "11ª Volta")

PedraoMetadeEnduroLap12['GPS_Speed'].fillna(PedraoMetadeEnduroLap12['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap12['GPS_Speed'], bins = 10, label = "12ª Volta")

PedraoMetadeEnduroLap13['GPS_Speed'].fillna(PedraoMetadeEnduroLap13['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap13['GPS_Speed'], bins = 10, label = "13ª Volta")

PedraoMetadeEnduroLap15['GPS_Speed'].fillna(PedraoMetadeEnduroLap15['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap15['GPS_Speed'], bins = 10, label = "15ª Volta")
         
PedraoMetadeEnduroLap16['GPS_Speed'].fillna(PedraoMetadeEnduroLap16['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap16['GPS_Speed'], bins = 10, label = "16ª Volta")

PedraoMetadeEnduroLap17['GPS_Speed'].fillna(PedraoMetadeEnduroLap17['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap17['GPS_Speed'], bins = 10, label = "17ª Volta")

PedraoMetadeEnduroLap18['GPS_Speed'].fillna(PedraoMetadeEnduroLap18['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap18['GPS_Speed'], bins = 10, label = "18ª Volta")

PedraoMetadeEnduroLap19['GPS_Speed'].fillna(PedraoMetadeEnduroLap19['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap19['GPS_Speed'], bins = 10, label = "19ª Volta")

PedraoMetadeEnduroLap20['GPS_Speed'].fillna(PedraoMetadeEnduroLap20['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap20['GPS_Speed'], bins = 10, label = "20ª Volta")

PedraoMetadeEnduroLap21['GPS_Speed'].fillna(PedraoMetadeEnduroLap21['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap21['GPS_Speed'], bins = 10, label = "21ª Volta")

PedraoMetadeEnduroLap22['GPS_Speed'].fillna(PedraoMetadeEnduroLap22['GPS_Speed'].mean(), inplace=True)
plt.hist(PedraoMetadeEnduroLap22['GPS_Speed'], bins = 10, label = "22ª Volta")

plt.title('Histograma Velocidade na Metade Enduro Pedrao 1109')
plt.xlabel('GPS_Speed') 
plt.ylabel('Contagem de amostras')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
plt.show
plt.savefig('Histograma Velocidade na Metade Enduro Pedrao 1109')

# %%
# Gerando gráficos para casas que tem 1 quarto
trace1 = go.Scatter(x = PedraoLap10['GPS_LatAcc'], y = PedraoLap10['GPS_LonAcc'], name = 'Volta 1', mode = 'markers')
# Gráfico de caixa para casas com 2 quartos
trace2 = go.Scatter(x = PedraoLap20['GPS_LatAcc'], y = PedraoLap20['GPS_LonAcc'], name = 'Volta 2', mode = 'markers')
# Gráfico de caixa para casas com 3 quartos
trace3 = go.Scatter(x = PedraoLap3['GPS_LatAcc'], y = PedraoLap3['GPS_LonAcc'], name = 'Volta 3', mode = 'markers')
# Gráfico para casas de quatro quartos
trace4 = go.Scatter(x = PedraoLap4['GPS_LatAcc'], y = PedraoLap4['GPS_LonAcc'], name = 'Volta 4', mode = 'markers')

data = [trace1, trace2, trace3, trace4]
layout = go.Layout(title = 'Grafico GG Volta a Volta',
                   titlefont = {'family': 'Arial',
                                'size': 22,
                                'color': '#7f7f7f'},
                   xaxis = {'title': 'Aceleração Lateral'},
                   yaxis = {'title': 'Aceleração Longitudinal'},
                   paper_bgcolor = 'rgb(243, 243, 243)',
                   plot_bgcolor = 'rgb(243, 243, 243)')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div>                            <div id="38423c2b-6e38-4342-838a-11d263455d13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38423c2b-6e38-4342-838a-11d263455d13")) {                    Plotly.newPlot(                        "38423c2b-6e38-4342-838a-11d263455d13",                        [{"mode": "markers", "name": "Volta 1", "type": "scatter", "x": [-0.7203970000000001, -0.748376, -0.7566609999999999, -0.764946, -0.7732319999999999, -0.781517, -0.783429, -0.766221, -0.749013, -0.7318060000000001, -0.714598, -0.694554, -0.6660020000000001, -0.63745, -0.6088979999999999, -0.580346, -0.5526220000000001, -0.527384, -0.502146, -0.476908, -0.45166999999999996, -0.42863100000000004, -0.412188, -0.39574499999999996, -0.379302, -0.362859, -0.345779, -0.3
# ...

# %%
#Diagrama GG de aceleração longitudinal x aceleração lateral

plt.scatter(PedraoMetadeEnduroLap3['GPS_Speed'], PedraoMetadeEnduroLap3['RPM'], label="3ª Volta")
plt.scatter(PedraoMetadeEnduroLap4['GPS_Speed'], PedraoMetadeEnduroLap4['RPM'], label="4ª Volta")
plt.scatter(PedraoMetadeEnduroLap5['GPS_Speed'], PedraoMetadeEnduroLap5['RPM'], label="5ª Volta")
plt.scatter(PedraoMetadeEnduroLap6['GPS_Speed'], PedraoMetadeEnduroLap6['RPM'], label="6ª Volta")
plt.scatter(PedraoMetadeEnduroLap7['GPS_Speed'], PedraoMetadeEnduroLap7['RPM'], label="7ª Volta")
plt.scatter(PedraoMetadeEnduroLap8['GPS_Speed'], PedraoMetadeEnduroLap8['RPM'], label="8ª Volta")
plt.scatter(PedraoMetadeEnduroLap9['GPS_Speed'], PedraoMetadeEnduroLap9['RPM'], label="9ª Volta")
plt.scatter(PedraoMetadeEnduroLap10['GPS_Speed'], PedraoMetadeEnduroLap10['RPM'], label="10ª Volta")
plt.scatter(PedraoMetadeEnduroLap11['GPS_Speed'], PedraoMetadeEnduroLap11['RPM'], label="11ª Volta")
plt.scatter(PedraoMetadeEnduroLap12['GPS_Speed'], PedraoMetadeEnduroLap12['RPM'], label="12ª Volta")
plt.scatter(PedraoMetadeEnduroLap13['GPS_Speed'], PedraoMetadeEnduroLap13['RPM'], label="13ª Volta")
plt.scatter(PedraoMetadeEnduroLap15['GPS_Speed'], PedraoMetadeEnduroLap15['RPM'], label="15ª Volta")
plt.scatter(PedraoMetadeEnduroLap16['GPS_Speed'], PedraoMetadeEnduroLap16['RPM'], label="16ª Volta")
plt.scatter(PedraoMetadeEnduroLap17['GPS_Speed'], PedraoMetadeEnduroLap17['RPM'], label="17ª Volta")
plt.scatter(PedraoMetadeEnduroLap18['GPS_Speed'], PedraoMetadeEnduroLap18['RPM'], label="18ª Volta")
plt.scatter(PedraoMetadeEnduroLap19['GPS_Speed'], PedraoMetadeEnduroLap19['RPM'], label="19ª Volta")
plt.scatter(PedraoMetadeEnduroLap20['GPS_Speed'], PedraoMetadeEnduroLap20['RPM'], label="20ª Volta")
plt.scatter(PedraoMetadeEnduroLap21['GPS_Speed'], PedraoMetadeEnduroLap21['RPM'], label="21ª Volta")
plt.scatter(PedraoMetadeEnduroLap22['GPS_Speed'], PedraoMetadeEnduroLap22['RPM'], label="22ª Volta")

#mymodel = np.poly1d(np.polyfit(PedraoMetadeEnduroLap15['GPS_Speed'], PedraoMetadeEnduroLap15['RPM'], 1))
#myline = np.linspace(20, 35, 100)

#plt.scatter(PedraoMetadeEnduroLap15['GPS_Speed'], PedraoMetadeEnduroLap15['RPM'])
#plt.plot(myline, mymodel(myline))

#plt.ylim(-1.5, 1.5)
plt.title('Gráfico Velocidade x RPM na Metade Enduro Pedrao 1109') #adicionando o título
plt.xlabel('GPS_Speed')
plt.ylabel('RPM')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
plt.savefig('Gráfico Velocidade x RPM na Metade Enduro Pedrao 1109.png')
plt.show()

# %%
# Removendo dados de aceleração longitudinal acima de 0.7

PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 6000) & (PedraoLap3.GPS_Speed > 40)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 6000) & (PedraoLap4.GPS_Speed > 40)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 6000) & (PedraoLap6.GPS_Speed > 40)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 6000) & (PedraoLap7.GPS_Speed > 40)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 6000) & (PedraoLap8.GPS_Speed > 40)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 6000) & (PedraoLap9.GPS_Speed > 40)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 6000) & (PedraoLap10.GPS_Speed > 40)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 6000) & (PedraoLap11.GPS_Speed > 40)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 6000) & (PedraoLap12.GPS_Speed > 40)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 6000) & (PedraoLap13.GPS_Speed > 40)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 6000) & (PedraoLap14.GPS_Speed > 40)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 6000) & (PedraoLap15.GPS_Speed > 40)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 6000) & (PedraoLap16.GPS_Speed > 40)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 6000) & (PedraoLap18.GPS_Speed > 40)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 6000) & (PedraoLap20.GPS_Speed > 40)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 6000) & (PedraoLap21.GPS_Speed > 40)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 3000) & (PedraoLap3.GPS_Speed > 25)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 3000) & (PedraoLap4.GPS_Speed > 25)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 3000) & (PedraoLap6.GPS_Speed > 25)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 3000) & (PedraoLap7.GPS_Speed > 25)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 3000) & (PedraoLap8.GPS_Speed > 25)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 3000) & (PedraoLap9.GPS_Speed > 25)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 3000) & (PedraoLap10.GPS_Speed > 25)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 3000) & (PedraoLap11.GPS_Speed > 25)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 3000) & (PedraoLap12.GPS_Speed > 25)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 3000) & (PedraoLap13.GPS_Speed > 25)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 3000) & (PedraoLap14.GPS_Speed > 25)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 3000) & (PedraoLap15.GPS_Speed > 25)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 3000) & (PedraoLap16.GPS_Speed > 25)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 3000) & (PedraoLap18.GPS_Speed > 25)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 3000) & (PedraoLap20.GPS_Speed > 25)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 3000) & (PedraoLap21.GPS_Speed > 25)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 8000) & (PedraoLap3.GPS_Speed > 44)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 8000) & (PedraoLap4.GPS_Speed > 44)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 8000) & (PedraoLap6.GPS_Speed > 44)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 8000) & (PedraoLap7.GPS_Speed > 44)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 8000) & (PedraoLap8.GPS_Speed > 44)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 8000) & (PedraoLap9.GPS_Speed > 44)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 8000) & (PedraoLap10.GPS_Speed > 44)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 8000) & (PedraoLap11.GPS_Speed > 44)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 8000) & (PedraoLap12.GPS_Speed > 44)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 8000) & (PedraoLap13.GPS_Speed > 44)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 8000) & (PedraoLap14.GPS_Speed > 44)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 8000) & (PedraoLap15.GPS_Speed > 44)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 8000) & (PedraoLap16.GPS_Speed > 44)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 8000) & (PedraoLap18.GPS_Speed > 44)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 8000) & (PedraoLap20.GPS_Speed > 44)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 8000) & (PedraoLap21.GPS_Speed > 44)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 3800) & (PedraoLap3.GPS_Speed > 27)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 3800) & (PedraoLap4.GPS_Speed > 27)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 3800) & (PedraoLap6.GPS_Speed > 27)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 3800) & (PedraoLap7.GPS_Speed > 27)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 3800) & (PedraoLap8.GPS_Speed > 27)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 3800) & (PedraoLap9.GPS_Speed > 27)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 3800) & (PedraoLap10.GPS_Speed > 27)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 3800) & (PedraoLap11.GPS_Speed > 27)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 3800) & (PedraoLap12.GPS_Speed > 27)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 3800) & (PedraoLap13.GPS_Speed > 27)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 3800) & (PedraoLap14.GPS_Speed > 27)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 3800) & (PedraoLap15.GPS_Speed > 27)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 3800) & (PedraoLap16.GPS_Speed > 27)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 3800) & (PedraoLap18.GPS_Speed > 27)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 3800) & (PedraoLap20.GPS_Speed > 27)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 3800) & (PedraoLap21.GPS_Speed > 27)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 5000) & (PedraoLap3.GPS_Speed > 35)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 5000) & (PedraoLap4.GPS_Speed > 35)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 5000) & (PedraoLap6.GPS_Speed > 35)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 5000) & (PedraoLap7.GPS_Speed > 35)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 5000) & (PedraoLap8.GPS_Speed > 35)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 5000) & (PedraoLap9.GPS_Speed > 35)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 5000) & (PedraoLap10.GPS_Speed > 35)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 5000) & (PedraoLap11.GPS_Speed > 35)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 5000) & (PedraoLap12.GPS_Speed > 35)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 5000) & (PedraoLap13.GPS_Speed > 35)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 5000) & (PedraoLap14.GPS_Speed > 35)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 5000) & (PedraoLap15.GPS_Speed > 35)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 5000) & (PedraoLap16.GPS_Speed > 35)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 5000) & (PedraoLap18.GPS_Speed > 35)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 5000) & (PedraoLap20.GPS_Speed > 35)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 5000) & (PedraoLap21.GPS_Speed > 35)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 8700) & (PedraoLap3.GPS_Speed > 46)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 8700) & (PedraoLap4.GPS_Speed > 46)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 8700) & (PedraoLap6.GPS_Speed > 46)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 8700) & (PedraoLap7.GPS_Speed > 46)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 8700) & (PedraoLap8.GPS_Speed > 46)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 8700) & (PedraoLap9.GPS_Speed > 46)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 8700) & (PedraoLap10.GPS_Speed > 46)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 8700) & (PedraoLap11.GPS_Speed > 46)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 8700) & (PedraoLap12.GPS_Speed > 46)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 8700) & (PedraoLap13.GPS_Speed > 46)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 8700) & (PedraoLap14.GPS_Speed > 46)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 8700) & (PedraoLap15.GPS_Speed > 46)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 8700) & (PedraoLap16.GPS_Speed > 46)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 8700) & (PedraoLap18.GPS_Speed > 46)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 8700) & (PedraoLap20.GPS_Speed > 46)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 8700) & (PedraoLap21.GPS_Speed > 46)].index)

# %%
PedraoLap3 = PedraoLap3.drop(PedraoLap3[(PedraoLap3.RPM < 9000) & (PedraoLap3.GPS_Speed > 50)].index)
PedraoLap4 = PedraoLap4.drop(PedraoLap4[(PedraoLap4.RPM < 9000) & (PedraoLap4.GPS_Speed > 50)].index)
PedraoLap6 = PedraoLap6.drop(PedraoLap6[(PedraoLap6.RPM < 9000) & (PedraoLap6.GPS_Speed > 50)].index)
PedraoLap7 = PedraoLap7.drop(PedraoLap7[(PedraoLap7.RPM < 9000) & (PedraoLap7.GPS_Speed > 50)].index)
PedraoLap8 = PedraoLap8.drop(PedraoLap8[(PedraoLap8.RPM < 9000) & (PedraoLap8.GPS_Speed > 50)].index)
PedraoLap9 = PedraoLap9.drop(PedraoLap9[(PedraoLap9.RPM < 9000) & (PedraoLap9.GPS_Speed > 50)].index)
PedraoLap10 = PedraoLap10.drop(PedraoLap10[(PedraoLap10.RPM < 9000) & (PedraoLap10.GPS_Speed > 50)].index)
PedraoLap11 = PedraoLap11.drop(PedraoLap11[(PedraoLap11.RPM < 9000) & (PedraoLap11.GPS_Speed > 50)].index)
PedraoLap12 = PedraoLap12.drop(PedraoLap12[(PedraoLap12.RPM < 9000) & (PedraoLap12.GPS_Speed > 50)].index)
PedraoLap13 = PedraoLap13.drop(PedraoLap13[(PedraoLap13.RPM < 9000) & (PedraoLap13.GPS_Speed > 50)].index)
PedraoLap14 = PedraoLap14.drop(PedraoLap14[(PedraoLap14.RPM < 9000) & (PedraoLap14.GPS_Speed > 50)].index)
PedraoLap15 = PedraoLap15.drop(PedraoLap15[(PedraoLap15.RPM < 9000) & (PedraoLap15.GPS_Speed > 50)].index)
PedraoLap16 = PedraoLap16.drop(PedraoLap16[(PedraoLap16.RPM < 9000) & (PedraoLap16.GPS_Speed > 50)].index)
PedraoLap18 = PedraoLap18.drop(PedraoLap18[(PedraoLap18.RPM < 9000) & (PedraoLap18.GPS_Speed > 50)].index)
PedraoLap20 = PedraoLap20.drop(PedraoLap20[(PedraoLap20.RPM < 9000) & (PedraoLap20.GPS_Speed > 50)].index)
PedraoLap21 = PedraoLap21.drop(PedraoLap21[(PedraoLap21.RPM < 9000) & (PedraoLap21.GPS_Speed > 50)].index)

# %%
#Diagrama GG de aceleração longitudinal x aceleração lateral

plt.scatter(PedraoLap3['GPS_Speed'], PedraoLap3['RPM'], label="3ª Volta")
plt.scatter(PedraoLap4['GPS_Speed'], PedraoLap4['RPM'], label="4ª Volta")
#plt.scatter(PedraoLap5['GPS_Speed'], PedraoLap5['RPM'], label="5ª Volta")
plt.scatter(PedraoLap6['GPS_Speed'], PedraoLap6['RPM'], label="6ª Volta")
plt.scatter(PedraoLap7['GPS_Speed'], PedraoLap7['RPM'], label="7ª Volta")
plt.scatter(PedraoLap8['GPS_Speed'], PedraoLap8['RPM'], label="8ª Volta")
plt.scatter(PedraoLap9['GPS_Speed'], PedraoLap9['RPM'], label="9ª Volta")
plt.scatter(PedraoLap10['GPS_Speed'], PedraoLap10['RPM'], label="10ª Volta")
plt.scatter(PedraoLap11['GPS_Speed'], PedraoLap11['RPM'], label="11ª Volta")
plt.scatter(PedraoLap12['GPS_Speed'], PedraoLap12['RPM'], label="12ª Volta")
plt.scatter(PedraoLap13['GPS_Speed'], PedraoLap13['RPM'], label="13ª Volta")
plt.scatter(PedraoLap14['GPS_Speed'], PedraoLap14['RPM'], label="14ª Volta")
plt.scatter(PedraoLap15['GPS_Speed'], PedraoLap15['RPM'], label="15ª Volta")
plt.scatter(PedraoLap16['GPS_Speed'], PedraoLap16['RPM'], label="16ª Volta")
#plt.scatter(PedraoLap17['GPS_Speed'], PedraoLap17['RPM'], label="17ª Volta")
plt.scatter(PedraoLap18['GPS_Speed'], PedraoLap18['RPM'], label="18ª Volta")
#plt.scatter(PedraoLap19['GPS_Speed'], PedraoLap19['RPM'], label="19ª Volta")
plt.scatter(PedraoLap20['GPS_Speed'], PedraoLap20['RPM'], label="20ª Volta")
plt.scatter(PedraoLap21['GPS_Speed'], PedraoLap21['RPM'], label="21ª Volta")

#plt.ylim(-1.5, 1.5)
#plt.title('Gráfico GG') #adicionando o título
plt.xlabel('Velocidade')
plt.ylabel('RPM')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
plt.savefig('Gráficos RPM x Velocidade no teste 22 voltas.png')
plt.show()
