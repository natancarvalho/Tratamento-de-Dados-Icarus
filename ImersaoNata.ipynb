# %%
# Importando bibliotecas para análise
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as st
import plotly.offline as py
import plotly.graph_objs as go

from scipy.special import boxcox1p

py.init_notebook_mode(connected=True)

#Importando dados em CSV para um data frame
JaguarLap1 = pd.read_csv('./JaguarLap1.csv')
JaguarLap2 = pd.read_csv('./JaguarLap2.csv')
JaguarLap3 = pd.read_csv('./JaguarLap3.csv')
JaguarLap4 = pd.read_csv('./JaguarLap4.csv')
JaguarLap5 = pd.read_csv('./JaguarLap5.csv')
JaguarLap6 = pd.read_csv('./JaguarLap6.csv')
JaguarLap7 = pd.read_csv('./JaguarLap7.csv')

#Exibindo a quantidade de linhas x colunas do data frame
print(JaguarLap1.shape)
print(JaguarLap2.shape)
print(JaguarLap3.shape)
print(JaguarLap4.shape)
print(JaguarLap5.shape)
print(JaguarLap6.shape)
print(JaguarLap7.shape)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# (1364, 53)
# (1030, 53)
# (1036, 53)
# (1028, 53)
# (1029, 53)
# (1024, 53)
# (1339, 53)

# %%
JaguarLap1.describe ()

# %%
JaguarLap2.describe ()

# %%
JaguarLap3.describe()

# %%
JaguarLap1.head()

# %%
JaguarLap2.head()

# %%
JaguarLap3.head()

# %%
#Diagrama GG de aceleração longitudinal x aceleração lateral

plt.scatter(JaguarLap1['LatAcc'], JaguarLap1['LongAcc']*-1, label="1ª Volta")
plt.scatter(JaguarLap2['LatAcc'], JaguarLap2['LongAcc']*-1, label="2ª Volta")
plt.scatter(JaguarLap3['LatAcc'], JaguarLap3['LongAcc']*-1, label="3ª Volta")
plt.scatter(JaguarLap4['LatAcc'], JaguarLap4['LongAcc']*-1, label="4ª Volta")
plt.scatter(JaguarLap5['LatAcc'], JaguarLap5['LongAcc']*-1, label="5ª Volta")
plt.scatter(JaguarLap6['LatAcc'], JaguarLap6['LongAcc']*-1, label="6ª Volta")
plt.scatter(JaguarLap7['LatAcc'], JaguarLap7['LongAcc']*-1, label="7ª Volta")
plt.xlim(-1.7, 1.7)
plt.ylim(-1.7, 1.7)
plt.title('Gráfico GG no teste de Aceleração 2') #adicionando o título
plt.xlabel('Aceleração Lateral')
plt.ylabel('Aceleração Longitudinal')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
#plt.savefig('Gráficos GG no teste de Acelerecao 2.png')
plt.show()

# %%
#Exportar dados gerais do treino para Excel

#taLap1.describe().to_excel("Teste de aceleracao21.xlsx")
#taLap2.describe().to_excel("Teste de aceleracao22.xlsx")
#taLap3.describe().to_excel("Teste de aceleracao23.xlsx")
#taLap4.describe().to_excel("Teste de aceleracao24.xlsx")
#taLap5.describe().to_excel("Teste de aceleracao25.xlsx")
#taLap6.describe().to_excel("Teste de aceleracao26.xlsx")

# %%
#Graficos de Velocidade x Distância

plt.plot(JaguarLap1['Distance'], JaguarLap1['WHEELSPD'],label="1ª Volta")
plt.plot(JaguarLap2['Distance'], JaguarLap2['WHEELSPD'],label="2ª Volta")
plt.plot(JaguarLap3['Distance'], JaguarLap3['WHEELSPD'],label="3ª Volta")
plt.plot(JaguarLap4['Distance'], JaguarLap4['WHEELSPD'],label="4ª Volta")
plt.plot(JaguarLap5['Distance'], JaguarLap5['WHEELSPD'],label="5ª Volta")
plt.plot(JaguarLap6['Distance'], JaguarLap6['WHEELSPD'],label="6ª Volta")
plt.plot(JaguarLap7['Distance'], JaguarLap7['WHEELSPD'],label="7ª Volta")
plt.title('Gráfico de Vel. x Distância no teste de aceleração 2') #adicionando o título
plt.xlabel('Distância (Km)')
plt.ylabel('Velocidade (Km/h)')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
#plt.yticks(range(0, 54))
#plt.savefig('Gráfico de velocidade x distância no teste de aceleracao 2.png')
plt.show()

# %%
#Histogramas de RPM

#JaguarLap1['RPM'].fillna(JaguarLap1['RPM'].mean(), inplace=True)
#plt.hist(JaguarLap1['RPM'], bins = 10, label = "1ª Volta")

#JaguarLap2['RPM'].fillna(JaguarLap2['RPM'].mean(), inplace=True)
#plt.hist(JaguarLap2['RPM'], bins = 10, label = "2ª Volta")

#JaguarLap3['RPM'].fillna(JaguarLap3['RPM'].mean(), inplace=True)
#plt.hist(JaguarLap3['RPM'], bins = 10, label = "3ª Volta")

#JaguarLap4['RPM'].fillna(JaguarLap4['RPM'].mean(), inplace=True)
#plt.hist(JaguarLap4['RPM'], bins = 10, label = "4ª Volta")

#JaguarLap5['RPM'].fillna(JaguarLap5['RPM'].mean(), inplace=True)
#plt.hist(JaguarLap5['RPM'], bins = 10, label = "5ª Volta")
         
JaguarLap6['RPM'].fillna(JaguarLap6['RPM'].mean(), inplace=True)
plt.hist(JaguarLap6['RPM'], bins = 10, label = "6ª Volta")

plt.title('Histograma RPM Teste Acelerção 2')
plt.xlabel('RPM') 
plt.ylabel('Contagem de amostras')
plt.legend()
plt.show
#plt.savefig('Histograma RPM Teste Aceleracao 2')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Histogramas de velocidade

JaguarLap1['GPS_Speed'].fillna(JaguarLap1['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap1['GPS_Speed'], bins = 10, label = "1ª Volta")

JaguarLap2['GPS_Speed'].fillna(JaguarLap2['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap2['GPS_Speed'], bins = 10, label = "2ª Volta")

JaguarLap3['GPS_Speed'].fillna(JaguarLap3['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap3['GPS_Speed'], bins = 10, label = "3ª Volta")

JaguarLap4['GPS_Speed'].fillna(JaguarLap4['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap4['GPS_Speed'], bins = 10, label = "4ª Volta")

JaguarLap5['GPS_Speed'].fillna(JaguarLap5['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap5['GPS_Speed'], bins = 10, label = "5ª Volta")
         
JaguarLap6['GPS_Speed'].fillna(JaguarLap6['GPS_Speed'].mean(), inplace=True)
plt.hist(JaguarLap6['GPS_Speed'], bins = 10, label = "6ª Volta")
       
plt.xlabel('GPS_Speed') 
plt.ylabel('Contagem de amostras')
plt.legend()
plt.show()

# %%
plt.plot(JaguarLap1['GPS_Speed'], JaguarLap1['RPM'], label="1ª Volta")
plt.plot(JaguarLap2['GPS_Speed'], JaguarLap2['RPM'], label="2ª Volta")
plt.plot(JaguarLap3['GPS_Speed'], JaguarLap3['RPM'], label="3ª Volta")
plt.plot(JaguarLap4['GPS_Speed'], JaguarLap4['RPM'], label="4ª Volta")
plt.plot(JaguarLap5['GPS_Speed'], JaguarLap5['RPM'], label="5ª Volta")
plt.plot(JaguarLap6['GPS_Speed'], JaguarLap6['RPM'], label="6ª Volta")
#plt.xlim(-0.75, 0.75)
#plt.ylim(-0.7, 0.7)
plt.title('Gráfico GG no teste de Aceleração 2') #adicionando o título
plt.xlabel('Aceleração Lateral')
plt.ylabel('Aceleração Longitudinal')
plt.legend()
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('bmh')
#plt.savefig('Gráficos GG no teste de Acelerecao 2.png')
plt.show()

# %%
# Gerando gráficos para casas que tem 1 quarto
trace1 = go.Scatter(x = JaguarLap1['LatAcc'], y = JaguarLap1['LongAcc']*-1, name = 'Volta 1', mode = 'markers')
# Gráfico de caixa para casas com 2 quartos
trace2 = go.Scatter(x = JaguarLap2['LatAcc'], y = JaguarLap2['LongAcc']*-1, name = 'Volta 2', mode = 'markers')
# Gráfico de caixa para casas com 3 quartos
trace3 = go.Scatter(x = JaguarLap3['LatAcc'], y = JaguarLap3['LongAcc']*-1, name = 'Volta 3', mode = 'markers')
# Gráfico para casas de quatro quartos
trace4 = go.Scatter(x = JaguarLap4['LatAcc'], y = JaguarLap4['LongAcc']*-1, name = 'Volta 4', mode = 'markers')

data = [trace1, trace2, trace3, trace4]
layout = go.Layout(title = 'Grafico GG Volta a Volta',
                   titlefont = {'family': 'Arial',
                                'size': 22,
                                'color': '#7f7f7f'},
                   xaxis = {'title': 'Aceleração Lateral'},
                   yaxis = {'title': 'Aceleração Longitudinal'},
                   paper_bgcolor = 'rgb(243, 243, 243)',
                   plot_bgcolor = 'rgb(243, 243, 243)')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="79cd5fde-dbc0-4fce-923c-89efac65f36f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79cd5fde-dbc0-4fce-923c-89efac65f36f")) {
#                     Plotly.newPlot(
#                         '79cd5fde-dbc0-4fce-923c-89efac65f36f',
# ...

# %%
teste = pd.read_csv('./pre_definitivo.csv')
print(teste.shape)

trace = go.Scatter(x =teste['rpm'], y = teste['N*m'], mode = 'markers+lines')
                   
data = [trace]

layout = go.Layout(title='Maior Header 4x1x2.sum N*M',
                   yaxis={'title':'N*M'},
                   xaxis={'title': 'RPM'})

fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# (41, 2)
# <div>
#
#
#             <div id="137a4016-4175-4dd1-9160-2f1f1fd252b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("137a4016-4175-4dd1-9160-2f1f1fd252b6")) {
#                     Plotly.newPlot(
#                         '137a4016-4175-4dd1-9160-2f1f1fd252b6',
# ...
